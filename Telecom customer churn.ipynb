# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Data Analytics\Telecom customer churn\telecom churn data.csv")
da = pd.read_csv(r"D:\Data Analytics\Telecom customer churn\telecom churn data.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df[(df['InternetService'] == 'No')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 11    7469-LKBCI    Male              0      No         No      16
# 16    8191-XWSZG  Female              0      No         No      52
# 21    1680-VDCWW    Male              0     Yes         No      12
# 22    1066-JKSGK    Male              0      No         No       1
# 33    7310-EGVHZ    Male              0      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 7017  4807-IZYOZ  Female              0      No         No      51
# 7019  9710-NJERN  Female              0      No         No      39
# 7020  9837-FWLCH    Male              0     Yes        Yes      12
# 7030  0871-OPBXW  Female              0      No         No       2
# 7037  2569-WGERO  Female              0      No         No      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 11            Yes            No              No  No internet service  ...
# ...

# %%
da['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
da.drop('customerID', axis=1, inplace=True)

# %%
da['Churn'] = da['Churn'].str.strip().str.lower().map({'yes': 1, 'no': 0})

# %%
print(da['Churn'].isna().sum())
# Out:
# 0

# %%
binary_cols = ['gender', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
for col in binary_cols:
    da[col] = da[col].astype(str).str.strip().str.lower()
    da[col] = da[col].map({'yes': 1, 'no': 0, 'male': 1, 'female': 0})

# %%
multi_cols = ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
              'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
              'Contract', 'PaymentMethod']
da = pd.get_dummies(da, columns=multi_cols)

# %%
da['TotalCharges'] = pd.to_numeric(da['TotalCharges'], errors='coerce')

# %%
da.dropna(subset=['TotalCharges'], inplace=True)

# %%
da.shape
# Out:
# (7032, 41)

# %%
da['MonthlyCharges'] = pd.to_numeric(df['MonthlyCharges'], errors='coerce')

# %%
da.dropna(subset=['MonthlyCharges'], inplace=True)

# %%
da.shape
# Out:
# (7032, 41)

# %%
print(da.isna().sum())
# Out:
# gender                                     0
# SeniorCitizen                              0
# Partner                                    0
# Dependents                                 0
# tenure                                     0
# PhoneService                               0
# PaperlessBilling                           0
# MonthlyCharges                             0
# TotalCharges                               0
# Churn                                      0
# MultipleLines_No                           0
# MultipleLines_No phone service             0
# MultipleLines_Yes                          0
# InternetService_DSL                        0
# InternetService_Fiber optic                0
# InternetService_No                         0
# OnlineSecurity_No                          0
# OnlineSecurity_No internet service         0
# OnlineSecurity_Yes                         0
# OnlineBackup_No                            0
# OnlineBackup_No internet service           0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Churn', data=df)
plt.title('Churn Distribution')
# Out:
# Text(0.5, 1.0, 'Churn Distribution')

# %%
churned_per = round((df['Churn']=='Yes').sum()/len(df)*100,2)
print('Churn Percentage', churned_per ,'%')
# Out:
# Churn Percentage 26.54 %

# %%
sns.countplot(x='gender', hue='Churn', data=df)
plt.title('Gender-wise Churn')
# Out:
# Text(0.5, 1.0, 'Gender-wise Churn')

# %%
# 0 = Not a senior citizen ; 1 = Senior Citizen

# %%
sns.countplot(x='SeniorCitizen', hue='Churn', data=df)
plt.title('Senior Citizens and Churn')
# Out:
# Text(0.5, 1.0, 'Senior Citizens and Churn')

# %%
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack', bins=30)
plt.title('Tenure Distribution by Churn')
# Out:
# Text(0.5, 1.0, 'Tenure Distribution by Churn')

# %%
df['tenure'].max()
# Out:
# np.int64(72)

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title('Contract Type and Churn')
# Out:
# Text(0.5, 1.0, 'Contract Type and Churn')

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title('Monthly Charges and Churn')
# Out:
# Text(0.5, 1.0, 'Monthly Charges and Churn')

# %%
sns.boxplot(x='Churn', y='TotalCharges', data=df)
plt.title('Total Charges and Churn')
# Out:
# Text(0.5, 1.0, 'Total Charges and Churn')

# %%
sns.scatterplot(data=df, x='tenure', y='MonthlyCharges', hue='Churn')
plt.title('Tenure vs Monthly Charges by Churn')
# Out:
# Text(0.5, 1.0, 'Tenure vs Monthly Charges by Churn')

# %%
sns.scatterplot(data=df, x='tenure', y='TotalCharges', hue='Churn')
plt.title('Tenure vs Total Charges by Churn')
# Out:
# Text(0.5, 1.0, 'Tenure vs Total Charges by Churn')

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.dropna(subset=['TotalCharges'], inplace=True)

# %%
corr = df[['tenure', 'MonthlyCharges', 'TotalCharges', 'SeniorCitizen', 'Churn']].copy()
corr['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})  # convert target for correlation
sns.heatmap(corr.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
from sklearn.model_selection import train_test_split

# %%
print(da['Churn'].isna().sum())
# Out:
# 0

# %%
da
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
x = da.drop('Churn', axis=1) 
y = da['Churn']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, stratify=y, random_state=42)

# %%
print("Training set size:", x_train.shape)
print("Test set size:", x_test.shape)
# Out:
# Training set size: (5625, 40)
# Test set size: (1407, 40)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
model1 = LogisticRegression(max_iter=1000)
model1.fit(x_train,y_train)
y_pred1 = model1.predict(x_test)
accuracy1 = accuracy_score(y_test,y_pred1)
print("Accuracy:", accuracy1)
# Out:
# Accuracy: 0.8038379530916845

# %%
conf_matrix = confusion_matrix(y_test,y_pred1)
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1033
#            1       0.65      0.57      0.61       374
#
#     accuracy                           0.80      1407
#    macro avg       0.75      0.73      0.74      1407
# weighted avg       0.80      0.80      0.80      1407

# %%
from sklearn.metrics import roc_curve, roc_auc_score
y_proba = model1.predict_proba(x_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_proba):.2f}")
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2 = DecisionTreeClassifier()
model2.fit(x_train,y_train)
y_pred2 = model2.predict(x_test)
accuracy2 = accuracy_score(y_test,y_pred2)
print("Accuracy:", accuracy2)
# Out:
# Accuracy: 0.7292110874200426

# %%
conf_matrix = confusion_matrix(y_test,y_pred2)
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81      1033
#            1       0.49      0.51      0.50       374
#
#     accuracy                           0.73      1407
#    macro avg       0.65      0.66      0.66      1407
# weighted avg       0.73      0.73      0.73      1407

# %%
y_proba = model2.predict_proba(x_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_proba):.2f}")
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model3 = RandomForestClassifier()
model3.fit(x_train,y_train)
y_pred3 = model3.predict(x_test)
accuracy3 = accuracy_score(y_test,y_pred3)
print("Accuracy:", accuracy3)
# Out:
# Accuracy: 0.7889125799573561

# %%
conf_matrix = confusion_matrix(y_test,y_pred3)
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1033
#            1       0.63      0.50      0.56       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
y_proba = model3.predict_proba(x_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_proba):.2f}")
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
coefficients = pd.DataFrame({
    'Feature': x.columns,
    'Coefficient': model1.coef_[0]
}).sort_values(by='Coefficient', ascending=False)

# %%
print(coefficients.head(10)) 
print(coefficients.tail(10))
# Out:
#                            Feature  Coefficient
# 8                     TotalCharges     0.633786
# 13     InternetService_Fiber optic     0.408359
# 33         Contract_Month-to-month     0.319068
# 29                 StreamingTV_Yes     0.178281
# 32             StreamingMovies_Yes     0.171470
# 6                 PaperlessBilling     0.142578
# 15               OnlineSecurity_No     0.118231
# 11               MultipleLines_Yes     0.118061
# 38  PaymentMethod_Electronic check     0.113505
# 24                  TechSupport_No     0.108501
#                                 Feature  Coefficient
# 31  StreamingMovies_No internet service    -0.114809
# 14                   InternetService_No    -0.114809
# 25      TechSupport_No internet service    -0.114809
# 28      StreamingTV_No internet service    -0.114809
# 16   OnlineSecurity_No internet service    -0.114809
# 19     OnlineBackup_No internet service    -0.114809
# 35                    Contract_Two year    -0.324269
# ...

# %%
insights = {
    'Feature': ['TotalCharges', ' InternetService_Fiber optic', 'Contract_Month-to-month','tenure','MonthlyCharges','InternetService_DSL','Contract_Two year'],
    'Coefficient': [0.633, 0.408, 0.319,-1.345,-0.907,-0.327,-0.324],
    'Insight': [
        'Higher total spending slightly increases churn.',
        'Fiber users are more likely to churn.',
        'Monthly plans lead to higher churn.',
        'Longer-tenured customers churn far less.',
        'Surprisingly, higher monthly charges reduce churn.',
        'DSL users churn less compared to others.',
        'Two-year contracts reduce churn.'
    ],
    'Feature Request': [
        'Offer loyalty rewards for long-time, high-paying users.',
        'Improve fiber service quality or offer satisfaction surveys.',
        'Provide discounts or perks for switching to longer plans.',
        'Engage new users early with onboarding and retention offers.',
        'Bundle premium features to justify and retain high-payers.',
        'Highlight DSL plan reliability to new users.',
        'Promote long-term contract plans with added benefits.',
    ]
}

da_requests = pd.DataFrame(insights)
da_requests.to_csv('logistic_feature_requests.csv', index=False)

# %%
coefficients.to_csv("logistic_model_coefficients.csv", index=False)
